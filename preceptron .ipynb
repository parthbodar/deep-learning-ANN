# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
print(df.shape)
# Out:
# (100, 3)

# %%
plt.scatter(df['cgpa'],df['resume_score'])

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['cgpa'], df['resume_score'], color='green', label='Placed')
plt.xlabel('CGPA')
plt.ylabel('Placement Score')
plt.title('Placement Dataset Scatter Plot')
plt.legend()
plt.grid(True)
plt.show()

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values,y.values,clf=p,legend=2)
# Out:
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.datasets import make_classification
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=y, cmap='winter', s=100)
plt.show()

# %%
def preceptron(X,y):
    
    X = np.insert(X,0,1,axis = 1)
    weights = np.ones(X.shape[1])
    lr=0.1
    
    for i in range(1000):
            j = np.random.randint(0,100)
            y_hat = step(np.dot(X[j],weights))
            weights = weights + lr*(y[j]-y_hat)*X[j]
            
    return weights[0],weights[1:]

# %%
def step(z):
     return 1 if z<0 else 0

# %%
intercept_,coef_ = preceptron(X,y)

# %%
print(coef_)
print(intercept_)
# Out:
# [402.559 361.334]
# 51.700000000000465

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10, 6))

# Plotting the line
plt.plot(x_input, y_input, color='red', linewidth=3)

# Plotting the scatter plot
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=y, cmap='winter', s=100)

# Adjusting the y-axis limit
plt.ylim(-3, 2)

# Showing the plot
plt.show()

# %% [markdown]
# # perceptron loss function

# %%
from sklearn.datasets import make_classification
import numpy as np
X,y = make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,
                         n_classes=2,n_clusters_per_class=1,random_state=41,hypercube=False,class_sep=15)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
def perceptron(X,y):
    w1=w2=b=1
    lr = 0.1
    
    for j in range(1000):
        
        for i in range(X.shape[0]):
            
            z=w1*X[i][0] + w2*X[i][1] + b
            
            if z*y[i] < 0:
                w1 = w1 + lr*y[i]*X[i][0]
                w2 = w2 + lr*y[i]*X[i][1]
                b = b + lr*y[i]
                
    return w1,w2,b

# %%
w1,w2,b = perceptron(X,y)

# %%
b
# Out:
# 1.3000000000000003

# %%
w1
# Out:
# 1.006638570722407

# %%
m = -(w1/w2)
c = -(b/w2)

print(m,c)
# Out:
# -4.531321834268464 -5.851870329508209

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + c

plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
